# %%
import pandas as pd
import numpy as np
import datetime

# %% [markdown]
# <h1>БАЗОВАЯ ИНФА<h1>

# %%
df = pd.read_csv('fraud test.csv')
df
# Out:
#         Unnamed: 0 trans_date_trans_time        cc_num  \
# 0                0      21/06/2020 12:14  2.291160e+15
# 1                1      21/06/2020 12:14  3.573030e+15
# 2                2      21/06/2020 12:14  3.598220e+15
# 3                3      21/06/2020 12:15  3.591920e+15
# 4                4      21/06/2020 12:15  3.526830e+15
# ...            ...                   ...           ...
# 555714      555714      31/12/2020 23:59  3.056060e+13
# 555715      555715      31/12/2020 23:59  3.556610e+15
# 555716      555716      31/12/2020 23:59  6.011720e+15
# 555717      555717      31/12/2020 23:59  4.079770e+12
# 555718      555718      31/12/2020 23:59  4.170690e+15
#
#                                     merchant        category     amt    first  \
# 0                      fraud_Kirlin and Sons   personal_care    2.86     Jeff
# 1                       fraud_Sporer-Keebler   personal_care   29.84   Joanne
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555719 entries, 0 to 555718
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             555719 non-null  int64
#  1   trans_date_trans_time  555719 non-null  object
#  2   cc_num                 555719 non-null  float64
#  3   merchant               555719 non-null  object
#  4   category               555719 non-null  object
#  5   amt                    555719 non-null  float64
#  6   first                  555719 non-null  object
#  7   last                   555719 non-null  object
#  8   gender                 555719 non-null  object
#  9   street                 555719 non-null  object
#  10  city                   555719 non-null  object
#  11  state                  555719 non-null  object
#  12  zip                    555719 non-null  int64
#  13  lat                    555719 non-null  float64
# ...

# %%
df.shape
# Out:
# (555719, 23)

# %%
df['is_fraud'].value_counts()
# Out:
# is_fraud
# 0    553574
# 1      2145
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#           Unnamed: 0        cc_num            amt            zip  \
# count  555719.000000  5.557190e+05  555719.000000  555719.000000
# mean   277859.000000  4.178387e+17      69.392810   48842.628015
# std    160422.401459  1.309837e+18     156.745941   26855.283328
# min         0.000000  6.041621e+10       1.000000    1257.000000
# 25%    138929.500000  1.800430e+14       9.630000   26292.000000
# 50%    277859.000000  3.521420e+15      47.290000   48174.000000
# 75%    416788.500000  4.635330e+15      83.010000   72011.000000
# max    555718.000000  4.992350e+18   22768.110000   99921.000000
#
#                  lat           long      city_pop     unix_time  \
# count  555719.000000  555719.000000  5.557190e+05  5.557190e+05
# mean       38.543253     -90.231325  8.822189e+04  1.380679e+09
# std         5.061336      13.721780  3.003909e+05  5.201104e+06
# min        20.027100    -165.672300  2.300000e+01  1.371817e+09
# ...

# %% [markdown]
# <h1>Мини правки данных<h1>

# %%
df = pd.read_csv('fraud test.csv')
df1 = df.copy()

# %%
df1['merchant'] = df1['merchant'].str.replace("fraud_", "")

# %%
df1[['date', 'time']] = df1['trans_date_trans_time'].str.split(' ', expand=True)
df1.head(5)
# Out:
#    Unnamed: 0 trans_date_trans_time        cc_num  \
# 0           0      21/06/2020 12:14  2.291160e+15
# 1           1      21/06/2020 12:14  3.573030e+15
# 2           2      21/06/2020 12:14  3.598220e+15
# 3           3      21/06/2020 12:15  3.591920e+15
# 4           4      21/06/2020 12:15  3.526830e+15
#
#                          merchant        category    amt   first      last  \
# 0                 Kirlin and Sons   personal_care   2.86    Jeff   Elliott
# 1                  Sporer-Keebler   personal_care  29.84  Joanne  Williams
# 2  Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley     Lopez
# 3                     Haley Group        misc_pos  60.05   Brian  Williams
# 4                 Johnston-Casper          travel   3.19  Nathan    Massey
#
#   gender                       street  ... city_pop                     job  \
# 0      M            351 Darlene Green  ...   333497     Mechanical engineer
# ...

# %%
df1["time"]
# Out:
# 0         12:14
# 1         12:14
# 2         12:14
# 3         12:15
# 4         12:15
#           ...
# 555714    23:59
# 555715    23:59
# 555716    23:59
# 555717    23:59
# 555718    23:59
# Name: time, Length: 555719, dtype: object

# %%
df1['trans_date_trans_time'] = pd.to_datetime(df1['trans_date_trans_time'])
df1['date'] = pd.to_datetime(df1['date'])
df1['time'] = pd.to_datetime(df1['time'], format='%H:%M').dt.time
df1['hours'] = df1['trans_date_trans_time'].dt.hour
df1['month'] = df1['date'].dt.to_period('M').astype("str")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5380\382197120.py:1: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df1['trans_date_trans_time'] = pd.to_datetime(df1['trans_date_trans_time'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_5380\382197120.py:2: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df1['date'] = pd.to_datetime(df1['date'])

# %%
df1['dob'] = pd.to_datetime(df1['dob'])
df1['age'] = (2020  - df1['dob'].dt.year)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5380\4209606178.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df1['dob'] = pd.to_datetime(df1['dob'])

# %%
df1['age'].unique()
# Out:
# array([52, 30, 50, 33, 65, 29, 69, 48, 47, 64, 24, 44, 43, 83, 49, 32, 28,
#        23, 35, 63, 72, 90, 46, 56, 62, 25, 40, 51, 45, 59, 77, 41, 34, 26,
#        91, 86, 27, 21, 38, 22, 36, 42, 31, 53, 20, 71, 82, 54, 55, 75, 37,
#        16, 68, 39, 70, 17, 66, 60, 79, 58, 74, 67, 96, 57, 19, 61, 94, 73,
#        84, 85, 81, 78, 15, 76, 89, 93, 80, 92, 87, 88, 18])

# %%
df1.head(5)
# Out:
#    Unnamed: 0 trans_date_trans_time        cc_num  \
# 0           0   2020-06-21 12:14:00  2.291160e+15
# 1           1   2020-06-21 12:14:00  3.573030e+15
# 2           2   2020-06-21 12:14:00  3.598220e+15
# 3           3   2020-06-21 12:15:00  3.591920e+15
# 4           4   2020-06-21 12:15:00  3.526830e+15
#
#                          merchant        category    amt   first      last  \
# 0                 Kirlin and Sons   personal_care   2.86    Jeff   Elliott
# 1                  Sporer-Keebler   personal_care  29.84  Joanne  Williams
# 2  Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley     Lopez
# 3                     Haley Group        misc_pos  60.05   Brian  Williams
# 4                 Johnston-Casper          travel   3.19  Nathan    Massey
#
#   gender                       street  ...                         trans_num  \
# 0      M            351 Darlene Green  ...  2da90c7d74bd46a0caf3777415b3ebd3
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555719 entries, 0 to 555718
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             555719 non-null  int64
#  1   trans_date_trans_time  555719 non-null  datetime64[ns]
#  2   cc_num                 555719 non-null  float64
#  3   merchant               555719 non-null  object
#  4   category               555719 non-null  object
#  5   amt                    555719 non-null  float64
#  6   first                  555719 non-null  object
#  7   last                   555719 non-null  object
#  8   gender                 555719 non-null  object
#  9   street                 555719 non-null  object
#  10  city                   555719 non-null  object
#  11  state                  555719 non-null  object
#  12  zip                    555719 non-null  int64
#  13  lat                    555719 non-null  float64
# ...

# %% [markdown]
# <h1>Анализ данных<h1>

# %%
num_ones = df1['is_fraud'].eq(1).sum()

num_zero = df1['is_fraud'].eq(0).sum()
print(num_ones)
print(num_zero)
# Out:
# 2145
# 553574

# %%
fraud_time = df1.groupby('time')['is_fraud'].count()
fraud_time = fraud_time.sort_values()
fraud_time
# Out:
# time
# 05:16:00    247
# 06:37:00    249
# 08:58:00    250
# 07:50:00    250
# 11:35:00    250
#            ...
# 22:20:00    527
# 22:05:00    527
# 22:15:00    528
# 23:38:00    531
# 16:42:00    545
# Name: is_fraud, Length: 1440, dtype: int64

# %%
#у нас в данных с 6 месяца начало 
print('Сколько раз в месяц происходит мошенничество')
print(df1.groupby('month')['is_fraud'].count().sort_values())
# Out:
# Сколько раз в месяц происходит мошенничество
# month
# 2020-06     30058
# 2020-10     69348
# 2020-09     69533
# 2020-11     72635
# 2020-07     85848
# 2020-08     88759
# 2020-12    139538
# Name: is_fraud, dtype: int64

# %%
monthly_losses = df1.groupby('month')['is_fraud'].count().reset_index()

fig, ax = plt.subplots(figsize=(10, 6))
ax.bar(monthly_losses['month'], monthly_losses['is_fraud'])
ax.set_title('Кол.во мошенничества в месяц')
ax.set_xlabel('Месяц')
ax.set_ylabel('Кол.во мошенничества')
ax.grid()
plt.show()

# %%
print('Сколько в общем в месяц мы теряем денег!')
print(df1.groupby('month')['amt'].sum())
# Out:
# Сколько в общем в месяц мы теряем денег!
# month
# 2020-06    2079538.35
# 2020-07    5938212.74
# 2020-08    6133478.17
# 2020-09    4911000.08
# 2020-10    4868952.99
# 2020-11    5028587.73
# 2020-12    9603133.05
# Name: amt, dtype: float64

# %%
monthly_losses = df1.groupby('month')['amt'].sum().reset_index()

fig, ax = plt.subplots(figsize=(10, 6))
ax.bar(monthly_losses['month'], monthly_losses['amt'])
ax.set_title('Сколько в общем в месяц мы теряем денег!')
ax.set_xlabel('Месяц')
ax.set_ylabel('Сумма')
ax.grid()
plt.show()

# %%
print('По какой категории чаще всего происходит мошенничество')
print(df1.groupby('category')['is_fraud'].count().sort_values())
# Out:
# По какой категории чаще всего происходит мошенничество
# category
# travel            17449
# grocery_net       19426
# misc_net          27367
# misc_pos          34574
# health_fitness    36674
# food_dining       39268
# personal_care     39327
# entertainment     40104
# shopping_net      41779
# kids_pets         48692
# shopping_pos      49791
# home              52345
# grocery_pos       52553
# gas_transport     56370
# Name: is_fraud, dtype: int64

# %%
monthly_losses = df1.groupby('category')['is_fraud'].count().reset_index()

fig, ax = plt.subplots(figsize=(10, 6))
ax.bar(monthly_losses['category'], monthly_losses['is_fraud'])
ax.set_title('По какой категории чаще всего происходит мошенничество')
ax.set_xlabel('Кол.во мошенничества')
ax.set_ylabel('Категория')
plt.xticks(rotation=40)

ax.grid()
plt.show()

# %%
df1.groupby('gender')['is_fraud'].count()
# Out:
# gender
# F    304886
# M    250833
# Name: is_fraud, dtype: int64

# %%
#city_pop 
df1.groupby('city_pop')['is_fraud'].count().sort_values()
# Out:
# city_pop
# 1071          6
# 6263          8
# 20226         9
# 837792        9
# 6910         10
#            ...
# 1766       1982
# 241        2045
# 1595797    2182
# 1312922    2222
# 606        2553
# Name: is_fraud, Length: 835, dtype: int64

# %%
df1.groupby('job')['is_fraud'].count().sort_values()
# Out:
# job
# Engineer, water                     8
# Software engineer                  11
# Operational investment banker      11
# Engineer, civil (consulting)      194
# Merchandiser, retail              195
#                                  ...
# Designer, ceramics/pottery       3463
# Naval architect                  3750
# Surveyor, land/geomatics         3756
# Exhibition designer              3968
# Film/video editor                4119
# Name: is_fraud, Length: 478, dtype: int64

# %%
age_fraud = df1.groupby('age')['is_fraud'].count().sort_index()
max_fraud_age = age_fraud.idxmax()
max_fraud_count = age_fraud.max()

print(max_fraud_age)
print(max_fraud_count)
print(age_fraud)
print(f'Максимальное кол.во мошенничества происходило с возрастом {max_fraud_age}. кол.во = {max_fraud_count}\n')
# Out:
# 48
# 19553
# age
# 15     963
# 16    3471
# 17    1858
# 18      12
# 19    2479
#       ...
# 91    2571
# 92    1721
# 93    1956
# 94    2720
# 96     199
# Name: is_fraud, Length: 81, dtype: int64
# Максимальное кол.во мошенничества происходило с возрастом 48. кол.во = 19553

# %%
monthly_losses = df1.groupby('age')['is_fraud'].count().reset_index()

fig, ax = plt.subplots(figsize=(10, 6))
ax.bar(monthly_losses['age'], monthly_losses['is_fraud'])
ax.set_title('По какой категории чаще всего происходит мошенничество')
ax.set_xlabel('Кол.во мошенничества')
ax.set_ylabel('Категория')
plt.xticks(rotation=40)

ax.grid()
plt.show()

# %% [markdown]
# <h1>Очистка данных<h1>

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555719 entries, 0 to 555718
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             555719 non-null  int64
#  1   trans_date_trans_time  555719 non-null  datetime64[ns]
#  2   cc_num                 555719 non-null  float64
#  3   merchant               555719 non-null  object
#  4   category               555719 non-null  object
#  5   amt                    555719 non-null  float64
#  6   first                  555719 non-null  object
#  7   last                   555719 non-null  object
#  8   gender                 555719 non-null  object
#  9   street                 555719 non-null  object
#  10  city                   555719 non-null  object
#  11  state                  555719 non-null  object
#  12  zip                    555719 non-null  int64
#  13  lat                    555719 non-null  float64
# ...

# %%
df1['gender'] = np.where(df1['gender'] == 'M', 1, 0)
df1['gender']
# Out:
# 0         1
# 1         0
# 2         0
# 3         1
# 4         1
#          ..
# 555714    1
# 555715    1
# 555716    0
# 555717    1
# 555718    1
# Name: gender, Length: 555719, dtype: int32

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'trans_date_trans_time', 'cc_num', 'merchant', 'category',
#        'amt', 'first', 'last', 'gender', 'street', 'city', 'state', 'zip',
#        'lat', 'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time',
#        'merch_lat', 'merch_long', 'is_fraud', 'date', 'time', 'hours', 'month',
#        'age'],
#       dtype='object')

# %%
df1 = df1.drop(['cc_num','merchant','category','first','last','street','city','state','job','dob','trans_num','unix_time', 'trans_date_trans_time','date', 'time'], axis = 1)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555719 entries, 0 to 555718
# Data columns (total 13 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  555719 non-null  int64
#  1   amt         555719 non-null  float64
#  2   gender      555719 non-null  int32
#  3   zip         555719 non-null  int64
#  4   lat         555719 non-null  float64
#  5   long        555719 non-null  float64
#  6   city_pop    555719 non-null  int64
#  7   merch_lat   555719 non-null  float64
#  8   merch_long  555719 non-null  float64
#  9   is_fraud    555719 non-null  int64
#  10  hours       555719 non-null  int32
#  11  month       555719 non-null  object
#  12  age         555719 non-null  int32
# dtypes: float64(5), int32(3), int64(4), object(1)
# memory usage: 48.8+ MB

# %%
df1['new_month'] = pd.to_datetime(df1['month']).dt.month
df1['new_month']
# Out:
# 0          6
# 1          6
# 2          6
# 3          6
# 4          6
#           ..
# 555714    12
# 555715    12
# 555716    12
# 555717    12
# 555718    12
# Name: new_month, Length: 555719, dtype: int32

# %%
df1 = df1.drop('month', axis = 1)

# %% [markdown]
# <h1>Логистическая регрессия<h1>

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score, StratifiedKFold

# %%
X = df1.drop(["is_fraud", "Unnamed: 0"], axis=1)
y = df1['is_fraud']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.5, random_state=42)

# %%
log_reg = LogisticRegression()

# %%
log_reg.fit(X_train, y_train)
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
X_test
# Out:
#           amt  gender    zip      lat      long  city_pop  merch_lat  \
# 119106   1.07       0   6441  41.4682  -72.5751      5438  41.240083
# 179292  94.99       1  74047  35.8896  -96.0887      7163  35.156537
# 540729  31.28       0  64630  40.0290  -93.1607       602  39.888665
# 374360  73.06       1  74047  35.8896  -96.0887      7163  36.734101
# 314574   9.99       0  51521  41.4768  -95.3509      2036  40.922072
# ...       ...     ...    ...      ...       ...       ...        ...
# 346401  33.05       1  35776  34.6689  -86.2296      3395  35.358964
# 99605   15.67       0  16858  41.0001  -78.2357      3688  40.622819
# 247984   6.53       1  99783  64.7556 -165.6723       145  65.751603
# 456268   5.20       1  29455  32.8357  -79.8217     20478  32.714843
# 86845   98.09       0  82227  42.7300 -104.7024       241  42.672316
#
#         merch_long  hours  age  new_month
# 119106  -71.837788      7   56          8
# 179292  -95.806648     14   38          8
# ...

# %%
coefficients = log_reg.coef_

avg_importance = np.mean(np.abs(coefficients), axis=0)
feature_importance = pd.DataFrame({'Feature': X.columns, 'Importance': avg_importance})
feature_importance = feature_importance.sort_values('Importance', ascending=True)
feature_importance.plot(x='Feature', y='Importance', kind='barh', figsize=(10, 6))
# Out:
# <Axes: ylabel='Feature'>

# %% [markdown]
# long - долгота местоположения владельца
# merch_long - долгота местоположения торговой точки

# %%
y_log_pred = log_reg.predict(X_test)

# %%
y_log_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
y_test
# Out:
# 119106    0
# 179292    0
# 540729    0
# 374360    0
# 314574    0
#          ..
# 346401    0
# 99605     0
# 247984    0
# 456268    0
# 86845     0
# Name: is_fraud, Length: 277860, dtype: int64

# %%
from sklearn.metrics import roc_auc_score

# %%
roc_auc_score(y_train, train_preds)
roc_auc_score(y_test, test_preds)
# Out:
# 0.9363808344687359

# %%
roc_auc_score(y_test, test_preds)
# Out:
# 0.9363808344687359

# %%
ASlog = accuracy_score(y_test, y_log_pred)
y_pred_proba_log = log_reg.predict_proba(X_test)[::, 1]
fpr, tpr, _ = metrics.roc_curve(y_test, y_log_pred)
Auclog = metrics.roc_auc_score(y_test, y_log_pred)


print('Accuracy score: ', ASlog)
print('Auc:', Auclog)
# Out:
# Accuracy score:  0.995738861297056
# Auc: 0.49981573679989016

# %%
pd.crosstab(y_test, y_log_pred, margins=True)
# Out:
# col_0          0    1     All
# is_fraud
# 0         276676  102  276778
# 1           1082    0    1082
# All       277758  102  277860

# %%
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label="AUC=" + str(Auclog))
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--', label='Random Guessing (AUC = 0.5)')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.grid()
plt.show()

# %% [markdown]
# <h1>Лес!<h1>

# %%
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# forest_mas = {}
# for i in range(1, 101):
#     forest = RandomForestClassifier(criterion='gini',
#                                     n_estimators=i,
#                                     random_state=1,
#                                     n_jobs=2)
#     forest.fit(X_train, y_train)
#     y_pred_forest = forest.predict(X_test)
#     forest_mas[i] = accuracy_score(y_test, y_pred_forest)
#
# print(forest_mas.max())

# %%
forest = RandomForestClassifier(criterion='gini',
                                    n_estimators=50,
                                    random_state=1,
                                    n_jobs=-1)

# %%
forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=20, n_jobs=2, random_state=1)

# %%
train_preds = forest.predict_proba(X_train)[:,1]
test_preds =  forest.predict_proba(X_test)[:,1]

# %%
roc_auc_score(y_train, train_preds)
# Out:
# 0.9999999133343285

# %%
roc_auc_score(y_test, test_preds)
# Out:
# 0.9119211652160713

# %%
y_pred_forest = forest.predict(X_test)

# %%
ASforest = accuracy_score(y_test, y_pred_forest)
RocAuc = metrics.roc_auc_score(y_test, y_pred_forest)

y_pred_proba_forest = log_reg.predict_proba(X_test)[::, 1]
fpr, tpr, _ = metrics.roc_curve(y_test, y_pred_proba_forest)
AucForest = metrics.roc_auc_score(y_test, y_pred_proba_forest)


print('Accuracy score: ', ASlog)
print('Auc:', AucForest)
# Out:
# Accuracy score:  0.995738861297056
# Auc: 0.7940947828370265

# %%
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label="AUC=" + str(AucForest))
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--', label='Random Guessing (AUC = 0.5)')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.grid()
plt.show()

# %%
pd.crosstab(y_test, y_pred_forest, margins=True)
# Out:
# col_0          0    1     All
# is_fraud
# 0         276718   60  276778
# 1            578  504    1082
# All       277296  564  277860

# %% [markdown]
#  k-fold кросс-валидация

# %%
val_score_forest = cross_val_score(forest, X, y, cv=5)

# %%
print("Accuracy scores for each fold:", val_score_forest)
print("Mean accuracy:", val_score_forest.mean())
# Out:
# Accuracy scores for each fold: [0.99697689 0.99723782 0.99692291 0.54131577 0.99641903]
# Mean accuracy: 0.9057744843068951

# %%
skf = StratifiedKFold(n_splits=5)

# %%
scores = cross_val_score(forest, X, y, cv=skf)

# %%
print("Accuracy scores for each fold:", scores)
print("Mean accuracy:", scores.mean())

# %% [markdown]
# <h1>KNN<h1>

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsClassifier

# %%
scaler = MinMaxScaler()

# %%
X = scaler.fit_transform(df1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
knn = KNeighborsClassifier(n_neighbors=1)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
knn_pred = knn.predict(X_test)

# %%
ASknn = accuracy_score(y_test, knn_pred)

y_pred_proba_knn = knn.predict_proba(X_test)[::, 1]
fpr, tpr, _ = metrics.roc_curve(y_test, y_pred_proba_knn)
Auc = metrics.roc_auc_score(y_test, y_pred_proba_knn)
Auc


print('Accuracy score: ', ASknn)
print('Auc:', Auc)
# Out:
# Accuracy score:  1.0
# Auc: 1.0

# %%
pd.crosstab(y_test, knn_pred, margins=True)
# Out:
# col_0          0    1     All
# is_fraud
# 0         166061    0  166061
# 1              0  655     655
# All       166061  655  166716

# %%
error_rate = []

for i in range(1, 40):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train)
    pred_i = knn.predict(X_test)
    
    error_rate.append(np.mean(pred_i != y_test))

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(1, 40), error_rate, color='blue', linestyle='--', markersize=10, markerfacecolor='red', marker='o')
plt.title('K versus Error rate')

plt.xlabel('K')
plt.ylabel('Error rate')
